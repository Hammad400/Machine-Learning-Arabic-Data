# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c53c67dd-74a9-421c-b767-894f5cfcc03d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c53c67dd-74a9-421c-b767-894f5cfcc03d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving الدوار-الثامن.csv to الدوار-الثامن.csv

# %%
df=pd.read_csv('الدوار-الثامن.csv',encoding = 'utf-8')
df
# Out:
#       Accident_ID النوع                التاريخ  السرعة  ع.اصابات بسيطة  \
# 0         1523897   صدم         2/1/2017 17:31      40               0
# 1         1523897   صدم         2/1/2017 17:31      40               0
# 2         1525376   صدم         6/1/2017 14:30      40               0
# 3         1525376   صدم         6/1/2017 14:30      40               0
# 4         1526309   صدم         11/1/2017 6:57      40               0
# ...           ...   ...                    ...     ...             ...
# 2582      2546273   صدم  12/28/2021 9:42:00 PM      60               0
# 2583      2547283   صدم  12/30/2021 7:07:00 PM      60               0
# 2584      2547283   صدم  12/30/2021 7:07:00 PM      60               0
# 2585      2547283   صدم  12/30/2021 7:07:00 PM      60               0
# 2586      2547283   صدم  12/30/2021 7:07:00 PM      60               0
#
#       ع.اصابات بليغة  ع.اصابات الوفاه  ع.اصابات متوسطة  \
# 0                  0                0                0
# 1                  0                0                0
# 2                  0                0                0
# 3                  0                0                0
# 4                  0                0                0
# ...              ...              ...              ...
# 2582               0                0                0
# 2583               0                0                0
# 2584               0                0                0
# 2585               0                0                0
# 2586               0                0                0
#
#                         مسارب الطريق سطح الطريق  ...                 الاضائة  \
# 0     اتجاهين غير مفصول بجزيرة وسطية        جاف  ...  ليل وطريق بإضاءة كافية
# 1     اتجاهين غير مفصول بجزيرة وسطية        جاف  ...  ليل وطريق بإضاءة كافية
# 2                         اتجاه واحد        جاف  ...                    نهار
# 3                         اتجاه واحد        جاف  ...                    نهار
# 4         اتجاهين مفصول بجزيرة وسطية        جاف  ...                    نهار
# ...                              ...        ...  ...                     ...
# 2582      اتجاهين مفصول بجزيرة وسطية        جاف  ...  ليل وطريق بإضاءة كافية
# 2583      اتجاهين مفصول بجزيرة وسطية        جاف  ...  ليل وطريق بإضاءة كافية
# 2584      اتجاهين مفصول بجزيرة وسطية        جاف  ...  ليل وطريق بإضاءة كافية
# 2585      اتجاهين مفصول بجزيرة وسطية        جاف  ...  ليل وطريق بإضاءة كافية
# 2586      اتجاهين مفصول بجزيرة وسطية        جاف  ...  ليل وطريق بإضاءة كافية
#
#      الطقس    خصائص طريق                                         خطأ السائق  \
# 0     صافي  مستقيم مستوي                                            لا يوجد
# 1     صافي  مستقيم مستوي                 عدم ترك السائق مسافة التتابع الامن
# 2     صافي  مستقيم مستوي  قيادة المركبة دون اخذ احتياطات السلامة المروري...
# 3     صافي  مستقيم مستوي                                            لا يوجد
# 4     صافي  مستقيم مستوي                                            لا يوجد
# ...    ...           ...                                                ...
# 2582  صافي  مستقيم مستوي                                            لا يوجد
# 2583  صافي  مستقيم مستوي                 عدم ترك السائق مسافة التتابع الأمن
# 2584  صافي  مستقيم مستوي                                            لا يوجد
# 2585  صافي  مستقيم مستوي                                            لا يوجد
# 2586  صافي  مستقيم مستوي                                            لا يوجد
#
#                    محافظه       فئة المركبة           تاريخ الحادث  \
# 0     محافظة العاصمة عمان  سيارة ركوب صغيرة         2/1/2017 17:31
# 1     محافظة العاصمة عمان  سيارة ركوب صغيرة         2/1/2017 17:31
# 2     محافظة العاصمة عمان  سيارة ركوب صغيرة         6/1/2017 14:30
# 3     محافظة العاصمة عمان  سيارة ركوب صغيرة         6/1/2017 14:30
# 4     محافظة العاصمة عمان  سيارة ركوب صغيرة         11/1/2017 6:57
# ...                   ...               ...                    ...
# 2582  محافظة العاصمة عمان  سيارة ركوب صغيرة  12/28/2021 9:42:00 PM
# 2583  محافظة العاصمة عمان  سيارة ركوب صغيرة  12/30/2021 7:07:00 PM
# 2584  محافظة العاصمة عمان  سيارة ركوب صغيرة  12/30/2021 7:07:00 PM
# 2585  محافظة العاصمة عمان  سيارة ركوب صغيرة  12/30/2021 7:07:00 PM
# 2586  محافظة العاصمة عمان  سيارة ركوب صغيرة  12/30/2021 7:07:00 PM
#
#      عدد المركبات عمرالسائق جنس السائق
# 0               2      33.0        ذكر
# 1               2       NaN        NaN
# 2               2      23.0        ذكر
# 3               2      34.0        ذكر
# 4               2      35.0       انثى
# ...           ...       ...        ...
# 2582            2      47.0        ذكر
# 2583            4      45.0        ذكر
# 2584            4      24.0        ذكر
# 2585            4     121.0       انثى
# 2586            4      24.0       انثى
#
# [2587 rows x 23 columns]

# %%
df.shape
# Out:
# (2587, 23)

# %%
df.columns
# Out:
# Index(['Accident_ID', 'Type', 'Date', 'the speed', 'A. Minor injuries',
#        'A. Serious injuries', 'p. death injuries', 'A. Medium injuries',
#        'lanes of the road', 'road surface', 'Vehicle Nationality',
#        'category of licenses', 'road type', 'the lighting', 'the weather',
#        'Road properties', 'driver error', 'Conservative', 'Vehicle class',
#        'accident date', 'number of vehicles', 'age of the driver',
#        'Driver's gender'],
#       dtype='object')

# %%
Arabic_features=['النوع', 'التاريخ', 'السرعة', 'ع.اصابات بسيطة',
       'ع.اصابات بليغة', 'ع.اصابات الوفاه', 'ع.اصابات متوسطة', 'مسارب الطريق',
       'سطح الطريق', 'جنسية المركبة', 'فئه الرخصه', 'نوع الطريق', 'الاضائة',
       'الطقس', 'خصائص طريق', 'خطأ السائق', 'محافظه', 'فئة المركبة',
       'تاريخ الحادث', 'عدد المركبات', 'عمرالسائق', 'جنس السائق']

# %%
len(Arabic_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c60ea58ce98> in <module>
# ----> 1 len(Arabic_features)
#
# NameError: name 'Arabic_features' is not defined

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.0 MB/s
# Collecting hstspreload
#   Downloading hstspreload-2021.12.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 10.7 MB/s
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2021.10.8)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.2 MB/s
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.2 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.8 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16367 sha256=08a450994043b77c1c8efe77fb381eaa5a728521054d786e8f4b346426aad53c
#   Stored in directory: /root/.cache/pip/wheels/0c/be/fe/93a6a40ffe386e16089e44dad9018ebab9dc4cb9eb7eab65ae
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.12.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0

# %%
from googletrans import Translator
translator = Translator()
translator.translate("كيف حالكم",dest="en").text
#print(out_put.text)
# Out:
# 'How are you all'

# %%
columns=['Accident_ID','Type', 'date', 'velocity', 'p.s. minor injuries',
       'A. Serious Injuries', 'P. Death Injuries', 'A. Medium Injuries', 'Pathways of the Road',
       'Road Surface', 'Vehicle Nationality', 'License Class', 'Type of Road', 'Lighting',
       'Weather', 'Road characteristics', 'Driver error', 'Province', 'Vehicle class',
       'Accident date', 'Number of vehicles', 'Age of the driver', 'Gender of the driver']

# %%
len(columns)
# Out:
# 23

# %%
# for feature in Arabic_features:
#   df[feature]=df[feature].apply(lambda x:translator.translate(x,dest="en").text)

# %%
df
# Out:
#       Accident_ID    النوع                التاريخ السرعة ع.اصابات بسيطة  \
# 0         1523897  shocked         2/1/2017 17:31     40              0
# 1         1523897  shocked         2/1/2017 17:31     40              0
# 2         1525376  shocked         6/1/2017 14:30     40              0
# 3         1525376  shocked         6/1/2017 14:30     40              0
# 4         1526309  shocked         11/1/2017 6:57     40              0
# ...           ...      ...                    ...    ...            ...
# 2582      2546273  shocked  12/28/2021 9:42:00 PM     60              0
# 2583      2547283  shocked  12/30/2021 7:07:00 PM     60              0
# 2584      2547283  shocked  12/30/2021 7:07:00 PM     60              0
# 2585      2547283  shocked  12/30/2021 7:07:00 PM     60              0
# 2586      2547283  shocked  12/30/2021 7:07:00 PM     60              0
#
#      ع.اصابات بليغة ع.اصابات الوفاه ع.اصابات متوسطة  \
# 0                 0               0               0
# 1                 0               0               0
# 2                 0               0               0
# 3                 0               0               0
# 4                 0               0               0
# ...             ...             ...             ...
# 2582              0               0               0
# 2583              0               0               0
# 2584              0               0               0
# 2585              0               0               0
# 2586              0               0               0
#
#                                           مسارب الطريق سطح الطريق  ...  \
# 0     Two directions not separated by a central island        dry  ...
# 1     Two directions not separated by a central island        dry  ...
# 2                                              One-way        dry  ...
# 3                                              One-way        dry  ...
# 4                Two-way separated by a central island        dry  ...
# ...                                                ...        ...  ...
# 2582             Two-way separated by a central island        dry  ...
# 2583             Two-way separated by a central island        dry  ...
# 2584             Two-way separated by a central island        dry  ...
# 2585             Two-way separated by a central island        dry  ...
# 2586             Two-way separated by a central island        dry  ...
#
#                                الاضائة  الطقس     خصائص طريق  \
# 0     Night and road with enough light  Clear  flat straight
# 1     Night and road with enough light  Clear  flat straight
# 2                                  day  Clear  flat straight
# 3                                  day  Clear  flat straight
# 4                                  day  Clear  flat straight
# ...                                ...    ...            ...
# 2582  Night and road with enough light  Clear  flat straight
# 2583  Night and road with enough light  Clear  flat straight
# 2584  Night and road with enough light  Clear  flat straight
# 2585  Night and road with enough light  Clear  flat straight
# 2586  Night and road with enough light  Clear  flat straight
#
#                                              خطأ السائق  \
# 0                                           There is no
# 1     The driver should not leave the safe relay dis...
# 2     Driving a vehicle without taking the necessary...
# 3                                           There is no
# 4                                           There is no
# ...                                                 ...
# 2582                                        There is no
# 2583  The driver should not leave the safe relay dis...
# 2584                                        There is no
# 2585                                        There is no
# 2586                                        There is no
#
#                          محافظه       فئة المركبة           تاريخ الحادث  \
# 0     Capital Governorate Amman  mini ride on car         2/1/2017 17:31
# 1     Capital Governorate Amman  mini ride on car         2/1/2017 17:31
# 2     Capital Governorate Amman  mini ride on car         6/1/2017 14:30
# 3     Capital Governorate Amman  mini ride on car         6/1/2017 14:30
# 4     Capital Governorate Amman  mini ride on car         11/1/2017 6:57
# ...                         ...               ...                    ...
# 2582  Capital Governorate Amman  mini ride on car  12/28/2021 9:42:00 PM
# 2583  Capital Governorate Amman  mini ride on car  12/30/2021 7:07:00 PM
# 2584  Capital Governorate Amman  mini ride on car  12/30/2021 7:07:00 PM
# 2585  Capital Governorate Amman  mini ride on car  12/30/2021 7:07:00 PM
# 2586  Capital Governorate Amman  mini ride on car  12/30/2021 7:07:00 PM
#
#      عدد المركبات عمرالسائق جنس السائق
# 0               2      33.0        ذكر
# 1               2       NaN        NaN
# 2               2      23.0        ذكر
# 3               2      34.0        ذكر
# 4               2      35.0       انثى
# ...           ...       ...        ...
# 2582            2      47.0        ذكر
# 2583            4      45.0        ذكر
# 2584            4      24.0        ذكر
# 2585            4     121.0       انثى
# 2586            4      24.0       انثى
#
# [2587 rows x 23 columns]

# %%
for feature in Arabic_features:
  feature_name=translator.translate(feature,dest="en").text
  df.rename(columns = {feature:feature_name}, inplace = True)

# %%
df.to_csv("الدوار-الثامن_english.csv", index=False)
